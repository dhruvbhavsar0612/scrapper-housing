# %%
import pandas as pd

# %%
df = pd.read_csv('data_with_link.csv', index_col=[0])

# %%
df.head()
# Out:
#    अनु क्र.  दस्त क्र.              दस्त प्रकार  \
# 0       NaN        NaN                      NaN
# 1       1.0     4286.0            विकसनकरारनामा
# 2       2.0    13217.0                भाडेपट्टा
# 3       3.0     2449.0                  सेल डीड
# 4       4.0     8691.0  66-नोटीस ऑफ़ लिस पेंडंसी
#
#                          दू. नि. कार्यालय        वर्ष  \
# 0                                     NaN         NaN
# 1  सह दु.नि. अंधेरी 7                      10/03/2023
# 2  सह दु.नि. अंधेरी 7                      25/07/2023
# 3  सह दु.नि. अंधेरी 7                      09/02/2023
# 4  सह दु.नि. अंधेरी 7                      22/05/2023
#
#                                          लिहून देणार  \
# 0                                                NaN
# 1                    1) अजित सिंह करतार सिंह  चंडोक
# 2  1) श्रीमती चंद्रकलादेवी सोमाणी चॅरिटी ट्रस्ट त...
# 3  1) नूपुर अनिल कळके तर्फे मुखत्यार शैला  अनिल क...
# 4                                   1) प्रदीप  सोनी
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51 entries, 0 to 50
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   अनु क्र.          50 non-null     float64
#  1   दस्त क्र.         50 non-null     float64
#  2   दस्त प्रकार       50 non-null     object
#  3   दू. नि. कार्यालय  50 non-null     object
#  4   वर्ष              50 non-null     object
#  5   लिहून देणार       50 non-null     object
#  6   लिहून घेणार       50 non-null     object
#  7   इतर माहीती        50 non-null     object
#  8   सूची क्र. २       50 non-null     object
#  9   link              50 non-null     object
# dtypes: float64(2), object(8)
# memory usage: 4.4+ KB

# %%
df.dropna(axis=0, inplace=True)

# %%
last_col = df.columns[-2]
df.drop(columns=last_col, inplace=True)
df.rename(columns={'link':last_col}, inplace=True)

# %%
df
# Out:
#     अनु क्र.  दस्त क्र.               दस्त प्रकार  \
# 1        1.0     4286.0             विकसनकरारनामा
# 2        2.0    13217.0                 भाडेपट्टा
# 3        3.0     2449.0                   सेल डीड
# 4        4.0     8691.0   66-नोटीस ऑफ़ लिस पेंडंसी
# 5        5.0     3551.0      65-चुक दुरुस्ती पत्र
# 6        6.0     8043.0   डेव्हलपमेंट अँग्रीमेंट
# 7        7.0     5454.0                 भाडेपट्टा
# 8        8.0     5457.0                 भाडेपट्टा
# 9        9.0     7732.0          अभिहस्तांतरणपत्र
# 10      10.0     8895.0      65-चुक दुरुस्ती पत्र
# 11      11.0     8896.0      65-चुक दुरुस्ती पत्र
# 12      12.0     2389.0             प्रतिज्ञापत्र
# 13      13.0     7415.0             विकसनकरारनामा
# 14      14.0      212.0                   सेल डीड
# 15      15.0     7019.0   डेव्हलपमेंट अँग्रीमेंट
# 16      16.0     5868.0   डेव्हलपमेंट अँग्रीमेंट
# 17      17.0     5450.0                    लीजडीड
# 18      18.0     3753.0                   सेल डीड
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50 entries, 1 to 50
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   अनु क्र.          50 non-null     float64
#  1   दस्त क्र.         50 non-null     float64
#  2   दस्त प्रकार       50 non-null     object
#  3   दू. नि. कार्यालय  50 non-null     object
#  4   वर्ष              50 non-null     object
#  5   लिहून देणार       50 non-null     object
#  6   लिहून घेणार       50 non-null     object
#  7   इतर माहीती        50 non-null     object
#  8   सूची क्र. २       50 non-null     object
# dtypes: float64(2), object(7)
# memory usage: 3.9+ KB

# %%
df.isna()
# Out:
#     अनु क्र.  दस्त क्र.  दस्त प्रकार  दू. नि. कार्यालय   वर्ष  लिहून देणार  \
# 1      False      False        False             False  False        False
# 2      False      False        False             False  False        False
# 3      False      False        False             False  False        False
# 4      False      False        False             False  False        False
# 5      False      False        False             False  False        False
# 6      False      False        False             False  False        False
# 7      False      False        False             False  False        False
# 8      False      False        False             False  False        False
# 9      False      False        False             False  False        False
# 10     False      False        False             False  False        False
# 11     False      False        False             False  False        False
# ...

# %%
from googletrans import Translator

# %%
translator = Translator()

# Define the text you want to translate
text_to_translate = "Hello, how are you?"

# Use the translate method to translate the text to another language (e.g., Spanish)
translated_text = translator.translate(text_to_translate, src='en', dest='es')

# Print the translated text
print(translated_text.text)
# Out:
# ¿Hola, cómo estás?

# %%
import requests
from google.cloud import translate_v2 as translate

# %%
def translate_text(target: str, text: str) -> dict:
    """Translates text into the target language.

    Target must be an ISO 639-1 language code.
    See https://g.co/cloud/translate/v2/translate-reference#supported_languages
    """

    translate_client = translate.Client()

    if isinstance(text, bytes):
        text = text.decode("utf-8")

    # Text can also be a sequence of strings, in which case this method
    # will return a sequence of results for each text.
    result = translate_client.translate(text, target_language=target)

    print("Text: {}".format(result["input"]))
    print("Translation: {}".format(result["translatedText"]))
    print("Detected source language: {}".format(result["detectedSourceLanguage"]))

    return result

# %%
x = translate_text(text="दस्त प्रकार", target="en")
# Out:
# ---------------------------------------------------------------------------
# DefaultCredentialsError                   Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 x = translate_text(text="दस्त प्रकार", target="en")
#
# Cell In[6], line 8, in translate_text(target, text)
#       1 def translate_text(target: str, text: str) -> dict:
#       2     """Translates text into the target language.
#       3
#       4     Target must be an ISO 639-1 language code.
#       5     See https://g.co/cloud/translate/v2/translate-reference#supported_languages
#       6     """
# ----> 8     translate_client = translate.Client()
#      10     if isinstance(text, bytes):
#      11         text = text.decode("utf-8")
#
# File c:\Users\Admin\anaconda3\envs\scraping\lib\site-packages\google\cloud\translate_v2\client.py:82, in Client.__init__(self, target_language, credentials, _http, client_info, client_options)
#      73 def __init__(
#      74     self,
# ...
